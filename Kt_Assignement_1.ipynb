# %% [markdown]
# # CISC 121 – Assignment-1
#
# ## 🔗 Problem
# Fizz Buzz – https://leetcode.com/problems/fizz-buzz/
#
# Palindrome Number – https://leetcode.com/problems/palindrome-number/
#
# Reverse Integer – https://leetcode.com/problems/reverse-integer/
#
# Two Sum – https://leetcode.com/problems/two-sum/
#
# Valid Palindrome – https://leetcode.com/problems/valid-palindrome/

# %% [markdown]
# #  Problem 1

# %% [markdown]
# ## 1. Understanding & Breakdown
#
# _Understand the problem, inputs/outputs, constraints, and  write down your plan or steps to solve the problem or draw the flowchart using digital or real pen-paper. Insert the image._
#
# **AI Level 1** is allowed to understand the concept, but you need to sketch the problem down by yourself.
#
# **Your effort is more important than the accuracy for this section**

# %% [markdown]
# 1. FizzBuzz
#
#   For this question you are given a integer and have to return certain responses if it is divisible by a certain number.
#   I would create a for statement that conists of a if,elif,else statement to see if the integer is divisible by 3, 5, and both 3 and 5. Each if,elif,else would add an append to the asnwer if it is true if not it would move onto the next elif statment
#
# 2. Palidrome number
#
#   For this question you're supposed to check if the integer is a palidrome.
#   To do this I would turn the integer into a string so i could use the if function with s==s[::-1]: to reverse the string and check if it is a palidrome. If it is it would return true, if not it would return false.
#
# 3. Reverse number
#
#   This question is similar to palidrome number but considers the negative infront of the number and includes a restraint.
#   I would take a similar approach to the previous question with turning the integer into a string but i would include the restraint
#
# 4. Two Sum
#
#   In this problem you are given a list of ints and a target, you must find  two ints from the list that add up to the target number. I would  create a loop that repeats once for every item in the list, then use a nested loop to check if the selected int and the nested int sums to the target number, once it sums to the target, I would return the two ints.
#
# 5. Valid Palindrom
#
#   In this problem you have to figure out if a string is a palindrom after converting it to lowercase and removing all non-alphabetic characters. I would convert remove all non-alphabetic characters by using isascii() then compared the filtered string with the reversed string, if it is a palindrom it returns true, if not, returns false

# %% [markdown]
# ## 2. Peer Review & Draft Code
#
# **Review Guidance:**
# Visit the **"Solutions"** tab on LeetCode for the selected problem and review at least one top-rated solution. You may also search for relevant discussions or Q&A threads on **Stack Overflow** or other forums to understand how others approached the problem.
#
# Then, write your own version based on what you understood. The goal is not to copy but to apply what you learned. Always include links to the resources you reviewed.
#
# ---
#
# ### **Example Answer (for "Palindrome Number"):**
#
# I reviewed the top solution under the LeetCode “Solutions” tab and one post on Stack Overflow:
# https://stackoverflow.com/questions/17129222/how-to-check-if-a-number-is-palindrome-in-python
#
# I learned that I can reverse the integer using a loop with modulo and division instead of converting it to a string. Using this idea, I tried writing a function that reverses the number and compares it to the original.

# %%
##Problem 1
def fizzBuzz(n: int):
    answer = []
    for i in range (0, n):
      if i % 3 == 0 and i % 5 == 0:
        answer.append('FizzBuzz')
      elif i % 3 == 0:
        answer.append('Fizz')
      elif i % 5 == 0:
        answer.append('Buzz')
      else:
        answer.append(i)
    return answer

# %%
##Problem 2
def Palindrome(x: int):
  s=str(x)
  if s==s[::-1]:
    return True
  else:
    return False

# %%
##Problem 3
def reverse(x: int):
  if -(2**31) <= x <= (2**31 - 1):
    x=str(-x)
    return x[::-1]
  else:
    return 0

# %%
##Problem 4
def twoSum(nums: list[int], target: int):
  n=len(nums)
  for i in range (n):
    for j in range (i+1, n):
      if nums[i] + nums[j] == target:
        return [i, j]

# %%
##Problem 5
def isPalindrome(s: str):
      palindrome = [i.lower() for i in s if i.isalnum()]
      return palindrome == palindrome[::-1]

# %% [markdown]
# ## 3. Final Correct Code
#
# _This version must pass all required test cases and handle edge cases correctly._
#
# At this stage, you may:
# - Use reviewed solutions or programming AI tools (e.g., ChatGPT, GitHub Copilot) to refine and fix errors.
# - Refactor your draft to ensure accuracy and completeness.
#
#  **AI Level 4 is allowed**, but you **must include a disclaimer** that clearly states what tools you used, how you used them, and for which part of the code.

# %%
#Problem 1
def fizzBuzz(n: int):
    answer = []
    for i in range (1, n+1):
      if i % 3 == 0 and i % 5 == 0:
        answer.append('FizzBuzz')
      elif i % 3 == 0:
        answer.append('Fizz')
      elif i % 5 == 0:
        answer.append('Buzz')
      else:
        answer.append(i)
    return answer

# %%
##Problem 2
def Palindrome(x: int):
  s=str(x)
  if s==s[::-1]:
    return True
  else:
    return False

# %%
##Problem 3
def reverse(x: int):
  if x < 0:
    x = str(-x)
    x_reverse = -int(x[::-1])
  else:
    x = str(x)
    x_reverse = int(x[::-1])
  if -(2**31) <= x_reverse <= (2**31 - 1):
      return x_reverse
  else:
      return 0

# %%
##Problem 4
def twoSum(nums: list[int], target: int):
  n=len(nums)
  for i in range (n-1):
    for j in range (i+1, n):
      if nums[i] + nums[j] == target:
        return [i, j]

# %%
##Problem 5
def isPalindrome(s: str):
  palindrome = [i.lower() for i in s if i.isalnum()]
  return palindrome == palindrome[::-1]

# %% [markdown]
# Add the screenshot of output for all the test cases from your working solutions.

# %% [markdown]
# ![IMG_5088.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## 4. Review & Fixes
# _What did you improve from your draft? 2 fixes with your comments._

# %%
#Problem 1
#Draft version: list only reads from 0 to n-1 because by default the for loop reads up till n-1 instead of to n
      # For loop includes 0 which is not needed for this question because using a 0 would print an extra 'FizzBuzz'
def fizzBuzz(n: int):
    answer = []
    for i in range (0, n):
      if i % 3 == 0 and i % 5 == 0:
        answer.append('FizzBuzz')
      elif i % 3 == 0:
        answer.append('Fizz')
      elif i % 5 == 0:
        answer.append('Buzz')
      else:
        answer.append(i)
    return answer
#Final Version: for loop now reads up till n instead of n-1 & starts from 1 instead of 0, removing the extra 'FizzBuzz'
def fizzBuzz(n: int):
    answer = []
    for i in range (1, n+1):
      if i % 3 == 0 and i % 5 == 0:
        answer.append('FizzBuzz')
      elif i % 3 == 0:
        answer.append('Fizz')
      elif i % 5 == 0:
        answer.append('Buzz')
      else:
        answer.append(i)
    return answer

##Problem 2
#My solution was as optimized as provided solutions; nothing was altered
def Palindrome(x: int):
  s=str(x)
  if s==s[::-1]:
    return True
  else:
    return False

#Problem 3
#Draft version: Removes negative sign when given a negative integer, does not return 0 when out of constraint, & will not return 0 if negative out of restraint
def reverse(x: int):
  if -(2**31) <= x <= (2**31 - 1):
    x=str(-x)
    return x[::-1]
  else:
    return 0

#Fixed version: Will not remove negative if given a negative integer & will return 0 if out of constraint
def reverse(x: int):
  if x < 0:
    x = str(-x) #removes the (-) sign
    x_reverse = -int(x[::-1]) #reverses and puts negative back
  else:
    x = str(x)
    x_reverse = int(x[::-1])
  if -(2**31) <= x_reverse <= (2**31 - 1): #checks if reversed number is in restraint (both negative and positive)
      return x_reverse
  else:
      return 0

#Problem 4
#Draft version: Ran an unnesscary extra loop that does no checking because there is no j after it to pair with it
def twoSum(nums: list[int], target: int):
  n=len(nums)
  for i in range (n):
    for j in range (i+1, n):
      if nums[i] + nums[j] == target:
        return [i, j]
#Fixed Version: More efficient, removes the extra unnecessary loop
def twoSum(nums: list[int], target: int):
  n=len(nums)
  for i in range (n-1):
    for j in range (i+1, n):
      if nums[i] + nums[j] == target:
        return [i, j]
##Problem 5
#My solution was as optimized as provided solutions; nothing was altered
def isPalindrome(s: str):
  palindrome = [i.lower() for i in s if i.isalnum()]
  return palindrome == palindrome[::-1]

# %% [markdown]
# ## 5. Reflection on Your Contribution
# _Where did AI or Other's code helped or fail to help? What specific logic or debugging did you contribute yourself?_
#
# ## Example
# 1. I used ChatGPT (Level 4) to help identify an edge case where my draft code failed when the input string started with a closing bracket. I also used ChatGPT to help structure the final loop and mapping dictionary, but verified all logic myself by tracing the code.
#
# 2.  I used ChatGPT to help write the loop. But the code had an indentation error after the `if` block, which caused it to fail. I fixed the spacing and made sure the code runs correctly.
#
# 3. I used opensource code from Github. I found and fixed a logic bug where they used if s[i] == '(' or ')', which always returned True. I corrected it to properly check both conditions.

# %% [markdown]
# My Reflection
# 1. For question 1 I realized that I had actually incorrectly read the question, it specifically states 'Given an integer n, return a string array answer (1-indexed) where:' not start at 0. This was more of a reading error than a coding error.
# 3. I debugged by restructuring the negative case: first removing the minus sign, then reversing the digits, and finally reapplying the negative sign.
#   I also added a final range check to ensure that the reversed number, whether positive or negative, stays within the 32-bit signed integer constraint. If not, the function correctly returns 0.
# 4. I carefully reviewed the code and realized that the outer loop was iterating one last time even though the last i value had no j vlaue to pair with. Thus, I made the loop run till n-1 instead of n

# %% [markdown]
# 1. Your Name: Kelly Ha Tran
# 2. Section: 001
# 3. ID: 20397237
# 4. Github Link of this notebook (the link of Github Repo where you saved your notebook)
# 5. Chat (Saved Chat  with your AI tool in a shared Document link)[Optional]

# %% [markdown]
# # **The most important part of writing code is not the code itself, but the thinking that leads to it. Thank You**
